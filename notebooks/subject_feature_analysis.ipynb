# %%
import sys
import os

# Asegura que Python vea la carpeta raíz
sys.path.append(os.path.abspath('..'))

from src.utils.visualizer import generar_analisis_visual

# VERIFICA ESTA RUTA: 
# Debe coincidir exactamente con el nombre de tu carpeta en 'logs'
results_path = "../runs/run_20260128_131727/experimento_completo.csv"

if os.path.exists(results_path):
    top_features = generar_analisis_visual(results_path)
    print(top_features)
else:
    print(f"Error: No se encuentra el archivo en {os.path.abspath(results_path)}")
# Out:
# ...
# TOP 25 CARACTERÍSTICAS MÁS IMPORTANTES
# ...
# Característica #26  | Elegida por 16 sujetos
# Característica #69  | Elegida por 14 sujetos
# Característica #53  | Elegida por 13 sujetos
# Característica #58  | Elegida por 12 sujetos
# Característica #54  | Elegida por 12 sujetos
# Característica #84  | Elegida por 12 sujetos
# Característica #72  | Elegida por 11 sujetos
# Característica #44  | Elegida por 11 sujetos
# Característica #38  | Elegida por 11 sujetos
# Característica #46  | Elegida por 10 sujetos
# Característica #61  | Elegida por 10 sujetos
# Característica #33  | Elegida por 10 sujetos
# Característica #66  | Elegida por 10 sujetos
# Característica #76  | Elegida por 10 sujetos
# Característica #9   | Elegida por  9 sujetos
# Característica #1   | Elegida por  9 sujetos
# Característica #41  | Elegida por  9 sujetos
# Característica #55  | Elegida por  9 sujetos
# Característica #39  | Elegida por  9 sujetos
# Característica #8   | Elegida por  9 sujetos
# ...
